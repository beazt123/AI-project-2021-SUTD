# %%
import numpy as np
import pandas as pd
import os
from csv import QUOTE_NONE
from glob import glob
from tqdm import tqdm

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score

# %% [markdown]
# Load the data

# %%
df = pd.read_csv("numerical_data.csv")

# %%
df.info()

# %% [markdown]
# Split into features and targets

# %%
y = df["Retweeted"]
df.drop(columns=["Retweeted", "Retweets"], inplace=True)
X = df

# %% [markdown]
# Train-test-split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# Train

# %%
X_train = MinMaxScaler().fit_transform(X_train)
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)

# %% [markdown]
# Test the model

# %%
# from joblib import dump, load
# clf = load('RFClassifier.joblib')

# %%
X_test = MinMaxScaler().fit_transform(X_test)
y_test_arr = y_test.values
y_hat = clf.predict(X_test)

# %% [markdown]
# Evaluate the model

# %% [markdown]
# F1-score

# %%
f1_score(y_test_arr, y_hat)
# Out:
# 0.9592002710340404

# %% [markdown]
# #acc

# %%
accuracy = (y_test_arr == y_hat).sum() / len(y_hat)
print(100 * accuracy)
# Out:
# 96.36428724851436

# %% [markdown]
# Test the reloaded model

# %%
rfc = load('RFClassifier.joblib')

# %%
y_hat_reloaded = rfc.predict(X_test)
accuracy = (len(y_hat_reloaded) - np.abs(y_test_arr - y_hat_reloaded).sum()) / len(y_hat_reloaded)
print(100 * accuracy)
# Out:
# 96.36428724851436

# %%
def f(x,y):
    print(x)
    print(y)

data = (1,2)
f(*data)
# Out:
# 1
# 2
